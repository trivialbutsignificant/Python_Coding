# %%
#All the data of a triangle
import math
print("Type NA if the data is not available")
A=input("Enter the first angle: ")
B=input("Enter the second angle: ")
C=input("Enter the third angle: ")
a=input("Enter the length of the side opposite to the first angle: ")
b=input("Enter the length of the side opposite to the second angle: ")
c=input("Enter the length of the side opposite to the third angle: ")
if A!='NA':
    A=float(A)
if B!='NA':
    B=float(B)
if C!='NA':
    C=float(C)
if a!='NA':
    a=float(a)
if b!='NA':
    b=float(b)
if c!='NA':
    c=float(c)

# If all three angles are given and some or all sides are given
if A!='NA' and B!='NA' and C!='NA' and (A+B+C)!=180:
    print("Triangle is invalid")
if A!='NA' and B!='NA' and C!='NA' and a=='NA' and b=='NA' and c=='NA' and (A+B+C)==180:
    print("Infinite triangles exist")
elif A!='NA' and B!='NA' and C!='NA' and a!='NA' and b!='NA' and c!='NA' and (A+B+C)==180 and ((a+b)<=c or (a+c)<=b or (b+c)<=a):
    print("Triangle is invalid")
elif A!='NA' and B!='NA' and C!='NA' and (((a!='NA' or b!='NA') and c!='NA') or ((b!='NA' or c!='NA') and a!='NA') or ((a!='NA' or c!='NA') and b!='NA')) and (A+B+C)==180:
    if a!='NA' and b!='NA' and c=='NA':
        c=float((a/(math.sin(A*math.pi/180)))*(math.sin(C*math.pi/180)))
    if b!='NA' and c!='NA' and a=='NA':
        a=float(b/math.sin(B*math.pi/180)*math.sin(A*math.pi/180))
    if c!='NA'and a!='NA' and b=='NA':
        b=float(c/math.sin(C*math.pi/180)*math.sin(B*math.pi/180))
    if ((a+b)>=c or (a+c)>=b or (b+c)>=a):
        print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
    else:
        print("Triangle is invalid")
elif A!='NA' and B!='NA' and C!='NA' and (a!='NA' or b!='NA' or c!='NA') and (A+B+C)==180:
    if a!='NA' and b=='NA' and c=='NA':
        b=float(a/math.sin(A*math.pi/180)*math.sin(B*math.pi/180))
        c=float(a/math.sin(A*math.pi/180)*math.sin(C*math.pi/180))
    if b!='NA' and a=='NA' and c=='NA':
        c=float(b/math.sin(B*math.pi/180)*math.sin(C*math.pi/180))
        a=float(b/math.sin(B*math.pi/180)*math.sin(A*math.pi/180))
    if c!='NA' and b=='NA' and a=='NA':
        a=float(c/math.sin(C*math.pi/180)*math.sin(A*math.pi/180))
        b=float(c/math.sin(C*math.pi/180)*math.sin(B*math.pi/180))
    if ((a+b)>=c or (a+c)>=b or (b+c)>=a):
        print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
    else:
        print("Triangle is invalid")

#If all three sides are given and no angle is given
if A=='NA' and B=='NA' and C=='NA' and a!='NA' and b!='NA' and c!='NA' and ((a+b)<=c or (a+c)<=b or (b+c)<=a):
    print("Triangle is invalid")
elif A=='NA' and B=='NA' and C=='NA' and a!='NA' and b!='NA' and c!='NA':
    A=float(math.acos((b**2+c**2-a**2)/(2*b*c))*(180/math.pi))
    B=float(math.acos((a**2+c**2-b**2)/(2*a*c))*(180/math.pi))
    C=float(math.acos((a**2+b**2-c**2)/(2*a*b))*(180/math.pi))
    print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')

#If two angles and one side is given
if (A!='NA' and B!='NA' and C=='NA') or (B!='NA' and C!='NA' and A=='NA') or (C!='NA' and A!='NA' and B=='NA'):
    if A=='NA':
        A=float(180-B-C)
    if B=='NA':
        B=float(180-A-C)
    if C=='NA':
        C=float(180-A-B)
if (A!='NA' and B!='NA' and C!='NA') and ((a!='NA' and b=='NA' and c=='NA') or (a=='NA' and b!='NA' and c=='NA') or (a=='NA' and b=='NA' and c!='NA')):
    if a!='NA':
        b=float(a/math.sin(A*math.pi/180)*math.sin(B*math.pi/180))
        c=float(a/math.sin(A*math.pi/180)*math.sin(C*math.pi/180))
    if b!='NA':
        c=float(b/math.sin(B*math.pi/180)*math.sin(C*math.pi/180))
        a=float(b/math.sin(B*math.pi/180)*math.sin(A*math.pi/180))
    if c!='NA':
        a=float(c/math.sin(C*math.pi/180)*math.sin(A*math.pi/180))
        b=float(c/math.sin(C*math.pi/180)*math.sin(B*math.pi/180))
    if ((a+b)>=c or (a+c)>=b or (b+c)>=a):
        print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
    else:
        print("Triangle is invalid")

#If one angle and two sides are given
if ((A!='NA' and B=='NA' and C=='NA') or (A=='NA' and B!='NA' and C=='NA') or (A=='NA' and B=='NA' and C!='NA')) and ((a!='NA' and b!='NA') or (b!='NA' and c!='NA') or (a!='NA' and c!='NA')):
    if A!='NA':
        if a!='NA' and b!='NA':
            if A==90:
                c=float(math.sqrt(a**2-b**2))
                B=float((math.asin(b/a))*180/math.pi)
                C=float((math.asin(c/a))*180/math.pi)
                print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
            elif round(float(a**2-(b**2)*(math.sin(A*math.pi/180))**2),4)==0:
                c=b*math.cos(A*math.pi/180)
                B=90
                C=90-A
                print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
            elif float(a**2-(b*math.sin(A*math.pi/180))**2)<0:
                print("Triangle is invalid")
            elif float(a**2-(b*math.sin(A*math.pi/180))**2)>0:
                c=float(b*math.cos(A*math.pi/180)+math.sqrt(a**2-(b*math.sin(A*math.pi/180))**2))
                if c>0:
                    C=180-float(math.asin(math.sin(A*math.pi/180)*c/a)*180/math.pi)
                    B=180-A-C
                    print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
                c=float(b*math.cos(A*math.pi/180)-math.sqrt(a**2-(b*math.sin(A*math.pi/180))**2))
                if c>0:    
                    C=float(math.asin(math.sin(A*math.pi/180)*c/a)*180/math.pi)
                    B=180-A-C
                    print("Or\nFirst Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
        elif b!='NA' and c!='NA':
                a=float(math.sqrt(b**2+c**2-2*b*c*math.cos(A*math.pi/180)))
                B=float(math.asin(math.sin(A*math.pi/180)*b/a)*180/math.pi)
                C=float(math.asin(math.sin(A*math.pi/180)*c/a)*180/math.pi)
                print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
        elif a!='NA' and c!='NA':
            if A==90:
                b=float(math.sqrt(a**2-c**2))
                B=float((math.asin(b/a))*180/math.pi)
                C=float((math.asin(c/a))*180/math.pi)
                print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
            if round(float(a**2-(c**2)*(math.sin(A*math.pi/180))**2),4)==0:
                b=c*math.cos(A*math.pi/180)
                C=90
                B=90-A
                print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
            elif float(a**2-(c*math.sin(A*math.pi/180))**2)<0:
                print("Triangle is invalid")
            elif float(a**2-(c*math.sin(A*math.pi/180))**2)>0:
                b=float(c*math.cos(A*math.pi/180)+math.sqrt(a**2-(c*math.sin(A*math.pi/180))**2))
                if b>0:   
                    B=180-float(math.asin(math.sin(A*math.pi/180)*b/a)*180/math.pi)
                    C=180-A-B
                    print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
                b=float(c*math.cos(A*math.pi/180)-math.sqrt(a**2-(c*math.sin(A*math.pi/180))**2))
                if b>0:   
                    B=float(math.asin(math.sin(A*math.pi/180)*b/a)*180/math.pi)
                    C=180-A-B
                    print("Or\nFirst Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
    elif B!='NA':
        if a!='NA' and b!='NA':
            if B==90:
                c=float(math.sqrt(b**2-a**2))
                A=float((math.asin(a/b))*180/math.pi)
                C=float((math.asin(c/b))*180/math.pi)
                print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
            elif round(float(b**2-(a**2)*(math.sin(B*math.pi/180))**2),4)==0:
                c=a*math.cos(B*math.pi/180)
                A=90
                C=90-B
                print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
            elif float(b**2-(a*math.sin(B*math.pi/180))**2)<0:
                print("Triangle is invalid")
            elif float(b**2-(a*math.sin(B*math.pi/180))**2)>0:
                c=float(a*math.cos(B*math.pi/180)+math.sqrt(b**2-(a*math.sin(B*math.pi/180))**2))
                if c>0:
                    C=180-float(math.asin(math.sin(B*math.pi/180)*c/b)*180/math.pi)
                    A=180-B-C
                    print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
                c=float(a*math.cos(B*math.pi/180)-math.sqrt(b**2-(a*math.sin(B*math.pi/180))**2))
                if c>0:    
                    C=float(math.asin(math.sin(B*math.pi/180)*c/b)*180/math.pi)
                    A=180-B-C
                    print("Or\nFirst Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
        elif a!='NA' and c!='NA':
                b=float(math.sqrt(a**2+c**2-2*a*c*math.cos(B*math.pi/180)))
                A=float(math.asin(math.sin(B*math.pi/180)*a/b)*180/math.pi)
                C=float(math.asin(math.sin(B*math.pi/180)*c/b)*180/math.pi)
                print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
        elif b!='NA' and c!='NA':
            if B==90:
                a=float(math.sqrt(b**2-c**2))
                A=float((math.asin(a/b))*180/math.pi)
                C=float((math.asin(c/b))*180/math.pi)
                print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
            elif round(float(b**2-(c**2)*(math.sin(B*math.pi/180))**2),4)==0:
                a=c*math.cos(B*math.pi/180)
                C=90
                A=90-B
                print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
            elif float(b**2-(c*math.sin(B*math.pi/180))**2)<0:
                print("Triangle is invalid")
            elif float(b**2-(c*math.sin(B*math.pi/180))**2)>0:
                a=float(c*math.cos(B*math.pi/180)+math.sqrt(b**2-(c*math.sin(B*math.pi/180))**2))
                if a>0:
                    A=180-float(math.asin(math.sin(B*math.pi/180)*a/b)*180/math.pi)
                    C=180-B-A
                    print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
                a=float(c*math.cos(B*math.pi/180)-math.sqrt(b**2-(c*math.sin(B*math.pi/180))**2))
                if a>0:
                    A=float(math.asin(math.sin(B*math.pi/180)*a/b)*180/math.pi)
                    C=180-B-A
                    print("Or\nFirst Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
    elif C!='NA':
        if c!='NA' and b!='NA':
            if C==90:
                a=float(math.sqrt(c**2-b**2))
                A=float((math.asin(a/c))*180/math.pi)
                B=float((math.asin(b/c))*180/math.pi)
                print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
            elif round(float(c**2-(b**2)*(math.sin(C*math.pi/180))**2),4)==0:
                a=b*math.cos(C*math.pi/180)
                B=90
                A=90-B
                print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
            elif float(c**2-(b*math.sin(C*math.pi/180))**2)<0:
                print("Triangle is invalid")
            elif float(c**2-(b*math.sin(C*math.pi/180))**2)>0:
                a=float(b*math.cos(C*math.pi/180)+math.sqrt(c**2-(b*math.sin(C*math.pi/180))**2))
                if a>0:
                    A=180-float(math.asin(math.sin(C*math.pi/180)*a/c)*180/math.pi)
                    B=180-B-C
                    print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
                a=float(a*math.cos(B*math.pi/180)-math.sqrt(c**2-(b*math.sin(C*math.pi/180))**2))
                if a>0:    
                    A=float(math.asin(math.sin(C*math.pi/180)*a/c)*180/math.pi)
                    B=180-B-C
                    print("Or\nFirst Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
        elif a!='NA' and b!='NA':
                c=float(math.sqrt(a**2+b**2-2*a*b*math.cos(C*math.pi/180)))
                A=float(math.asin(math.sin(C*math.pi/180)*a/c)*180/math.pi)
                B=float(math.asin(math.sin(C*math.pi/180)*b/c)*180/math.pi)
                print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
        elif a!='NA' and c!='NA':
            if C==90:
                b=float(math.sqrt(c**2-a**2))
                B=float((math.asin(b/c))*180/math.pi)
                A=float((math.asin(a/c))*180/math.pi)
                print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
            elif round(float(c**2-(a**2)*(math.sin(C*math.pi/180))**2),4)==0:
                b=a*math.cos(C*math.pi/180)
                A=90
                B=90-A
                print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
            elif float(c**2-(a*math.sin(C*math.pi/180))**2)<0:
                print("Triangle is invalid")
            elif float(c**2-(a*math.sin(C*math.pi/180))**2)>0:
                b=float(a*math.cos(C*math.pi/180)+math.sqrt(c**2-(a*math.sin(C*math.pi/180))**2))
                if b>0:
                    B=180-float(math.asin(math.sin(C*math.pi/180)*b/c)*180/math.pi)
                    A=180-B-C
                    print("First Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
                b=float(a*math.cos(C*math.pi/180)-math.sqrt(c**2-(a*math.sin(C*math.pi/180))**2))
                if b>0:
                    B=float(math.asin(math.sin(C*math.pi/180)*b/c)*180/math.pi)
                    A=180-B-C
                    print("Or\nFirst Side = ",a,"\nSecond Side = ",b,"\nThird Side = ",c,"\nFirst Angle = ",A,chr(176),"\nSecond Angle = ",B,chr(176),"\nThird Angle = ",C,chr(176),sep='')
# Out:
# Type NA if the data is not available
# Enter the first angle: 90
# Enter the second angle: NA
# Enter the third angle: NA
# Enter the length of the side opposite to the first angle: 1
# Enter the length of the side opposite to the second angle: 0.5
# Enter the length of the side opposite to the third angle: NA
# First Side = 1.0
# Second Side = 0.5
# Third Side = 0.8660254037844386
# First Angle = 90.0°
# Second Angle = 29.999999999999996°
# Third Angle = 59.99999999999999°
